# %% [markdown]
# ## Cartilha Gráficos em Python

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Base de dados dos vídeos

# %%
df_videos = pd.read_excel('data/videosYT.xlsx', 'videos')
df_videos.head()
# Out:
#    Código Vídeo  Nº de Views  Nº de Likes  Nº de Dislikes  Nº Inscrições  \
# 0             1         3088          306               6              0
# 1             2         8026          690               8              8
# 2             3         8296          664               8              0
# 3             4         2534          266               5              0
# 4             5         5362          456              11              5
#
#   Responsável     Categoria
# 0      Daniel      Tutorial
# 1        Lira  Webscrapping
# 2        Lira     Automação
# 3      Daniel  Data Science
# 4        Lira  Data Science

# %% [markdown]
# # Gráficos Relacionais

# %% [markdown]
# ### Gráfico de Dispersão

# %%
scat_fig = sns.scatterplot(data=df_videos, x='Nº de Views', y='Nº de Likes', hue='Responsável', style='Responsável', palette=['red', 'black'])
plt.show(scat_fig)

# %% [markdown]
# ### Gráfico de Dispersão (Relacional)

# %%
rel_fig = sns.relplot(data=df_videos, x='Nº de Views', y='Nº de Likes', hue='Categoria', col='Responsável')
rel_fig.set_titles('O responsável desse gráfico é {col_name}')
plt.show(rel_fig)

# %% [markdown]
# ## Base de dados dos Inscritos

# %%
df_inscritos = pd.read_excel('data/videosYT.xlsx', 'Inscritos')
df_inscritos.head()
# Out:
#      Mês/Ano  Inscritos
# 0 2021-01-01       5000
# 1 2021-02-01       7249
# 2 2021-03-01       9004
# 3 2021-04-01      10182
# 4 2021-05-01      12210

# %% [markdown]
# ### Gráfico de Linha

# %%
line_fig = sns.lineplot(data=df_inscritos, x='Mês/Ano', y='Inscritos', color='orange')
plt.show(line_fig)

# %% [markdown]
# # Gráficos de Distribuição

# %% [markdown]
# ### Gráfico Histograma

# %%
hist_fig = sns.displot(kind='hist', data=df_videos, x='Nº de Likes', hue='Responsável', col='Responsável', rug=True)
plt.show(hist_fig)

# %% [markdown]
# ### Gráfico de  Densidade

# %%
hist_fig = sns.displot(kind='kde', data=df_videos, x='Nº de Likes')
plt.show(hist_fig)

# %% [markdown]
# ### Gráfico de Distribuição Empírica

# %%
hist_fig = sns.displot(kind='ecdf', data=df_videos, x='Nº de Likes')
plt.show(hist_fig)

# %% [markdown]
# # Gráficos Categoricos

# %% [markdown]
# ## Gráfico de Regressão

# %%
reg_fig = sns.regplot(data = df_videos, x = "Nº de Views", y = "Nº de Likes") 
plt.show(reg_fig)

# %%
lm_fig = sns.lmplot(data = df_videos, x = "Nº de Views", y = "Nº de Likes", hue='Responsável') 
plt.show(lm_fig)
